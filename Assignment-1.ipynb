# %% [markdown]
# # Data Science
#
# ## Lab Assignment-1

# %% [markdown]
# ### Part A

# %% [markdown]
# ### Q1. Checking the type of different variables
# Create the following variables:
# a = 25
# b = 12.5
# c = "Python"
# d = True
# Print the value and data type of each variable using type().

# %%
a=25
b=12.5
c="Python"
d=True

# %%
print("Value: ",a,", Data Type: ", type(a))
print("Value: ",b,", Data Type: ", type(b))
print("Value: ",c,", Data Type: ", type(c))
print("Value: ",d,", Data Type: ", type(d))
# Out:
# Value:  25 , Data Type:  <class 'int'>
# Value:  12.5 , Data Type:  <class 'float'>
# Value:  Python , Data Type:  <class 'str'>
# Value:  True , Data Type:  <class 'bool'>

# %% [markdown]
# ### Q2. Checking the type of different values
# Create variables containing an integer, float, string, Boolean value, and a list. Print the type of each
# variable.

# %%
a=25
b=12.53
c="My name is d"
d=True
e= [2, 4, 6, 'string', True, 93.341]
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>

# %% [markdown]
# ### Part B

# %% [markdown]
# ### Q3. Addition (+)
# Create two variables:
# a = 20
# b = 10
# Find and print their sum.
# Expected result: 30

# %%
a=20
b=10
c=a+b
print(c)
# Out:
# 30

# %% [markdown]
# ### Q4. Subtraction (-)
# Create two variables:
# a = 20
# b = 10
# Find and print a - b.
# Expected result: 10

# %%
a=20
b=10
c=a-b
print(c)
# Out:
# 10

# %% [markdown]
# ### Q5. Multiplication *
# Create two variables:
# a = 20
# b = 10
# Find and print a * b.
# Expected result: 200

# %%
a=20
b=10
c=a*b
print(c)
# Out:
# 200

# %% [markdown]
# ### Q6. Division /
# Create two variables:
# a = 20
# b = 10
# Find and print a / b.
# Expected result: 2.0

# %%
a=20
b=10
c=20/10
print(c)
# Out:
# 2.0

# %% [markdown]
# ### Q7. Modulus %
# Create two variables:
# a = 25
# b = 7
# Find and print the remainder using %.
# Expected result: 4

# %%
a=25
b=7
c=25%7
print(c)
# Out:
# 4

# %% [markdown]
# ### Q8. Floor Division //
# Create two variables:
# a = 24
# b = 7
# Find and print a // b.
# Expected result: 3

# %%
a=24
b=7
c=24//7
print(c)
# Out:
# 3

# %% [markdown]
# ### Q9. Exponent **
# Create two variables:
# a = 2
# b = 3
# Find and print a ** b.
# Expected result: 8

# %%
a=2
b=3
c=a**b
print(c)
# Out:
# 8

# %% [markdown]
# ### Part C – Comparison Operators

# %% [markdown]
# ### Q10. Equal to ==
# Create:
# a = 20
# b = 20
# Check whether a and b are equal using ==.

# %%
a=20
b=20
c=a==b
print(c)
# Out:
# True

# %% [markdown]
# ### Q11. Not equal to !=
# Create:
# a = 20
# b = 10
# Check whether a and b are not equal.

# %%
a=20
b=10
c=a!=b
print(c)
# Out:
# True

# %% [markdown]
# ### Q12. Less than <
# Create:
# a = 10
# b = 20
# Check whether a is less than b.

# %%
a=10
b=20
c=a<b
print(c)
# Out:
# True

# %% [markdown]
# ### Q13. Greater than >
# Create:
# a = 30
# b = 20
# Check whether a is greater than b.

# %%
a=30
b=20
c=a>b
print(c)
# Out:
# True

# %% [markdown]
# ### Q14. Less than or equal to <=
# Create:
# a = 20
# b = 20
# Check whether a is less than or equal to b.

# %%
a=20
b=20
c=a<=b
print(c)
# Out:
# True

# %% [markdown]
# ### Q15. Greater than or equal to >=
# Create:
# a = 25
# b = 20
# Check whether a is greater than or equal to b.

# %%
a=25
b=20
c=a>=b
print(c)
# Out:
# True

# %% [markdown]
# ### Part D – Assignment Operators

# %% [markdown]
# ### Q16. Assignment operator =
# Create a variable x and assign the value 50 to it. Print the value of x.

# %%
x=50
print(x)
# Out:
# 50

# %% [markdown]
# ### Q17. Addition assignment +=
# Write a program:
# x = 10
# x += 5
# Print the value of x.
# Expected output: 15

# %%
x=10
x+=5
print(x)
# Out:
# 15

# %% [markdown]
# ### Q18. Subtraction assignment -=
# Write a program:
# x = 20
# x -= 7
# Print the value of x.
# Expected output: 13

# %%
x=20
x-=7
print(x)
# Out:
# 13

# %% [markdown]
# ### Q19. Multiplication assignment *=
# Write a program:
# x = 5
# x *= 4
# Print the value of x.
# Expected output: 20

# %%
x=5
x*=4
print(x)
# Out:
# 20

# %% [markdown]
# ### Q20. Division assignment /=
# Write a program:
# x = 20
# x /= 4
# Print the value of x.
# Expected output: 5.0

# %%
x=20
x/=4
print(x)
# Out:
# 5.0

# %% [markdown]
# ### Q21. Modulus assignment %=
# Write a program:
# x = 17
# x %= 5
# Print the value of x.
# Expected output: 2

# %%
x=17
x%=5
print(x)
# Out:
# 2

# %% [markdown]
# ### Q22. Exponent assignment **=
# Write a program:
# x = 2
# x **= 4
# Print the value of x.
# Expected output: 16

# %%
x=2
x**=4
print(x)
# Out:
# 16

# %% [markdown]
# ### Q23. Floor division assignment //=
# Write a program:
# x = 25
# x //= 4
# Print the value of x.
# Expected output: 6

# %%
x=25
x//=4
print(x)
# Out:
# 6

# %% [markdown]
# ### Part E – Logical Operators

# %% [markdown]
# ### Q24. Logical AND and
# Create:
# a = 10
# b = 20
# Check and print the result of:
# a < b and b > 15

# %%
a=10
b=20
print(a<b and b>15)
# Out:
# True

# %% [markdown]
# ### Q25. Logical OR or
# Create:
# a = 10
# b = 20
# Check and print the result of:
# a > b or a < b

# %%
a=10
b=20
print(a>b or a<b)
# Out:
# True

# %% [markdown]
# ### Q26. Logical NOT not
# Create:
# a = 10
# b = 20
# Check and print the result of:
# not(a > b)

# %%
a=10
b=20
c=not(a>b)
print(c)
# Out:
# True

# %% [markdown]
# ### Q27. Combining logical operators
# Create:
# age = 20
# marks = 85
# Write expressions using and, or, and not to check conditions based on age and marks.

# %%
age =20
marks = 85
print(age>=18 and marks>40)
print(age>=18 or marks>=90)
print(not(age<18))
# Out:
# True
# True
# True

# %% [markdown]
# ### Part F – Bitwise Operators
# For the following questions, use:
# a = 10
# b = 6

# %%
a=10
b=6

# %% [markdown]
# ### Q28. Bitwise AND &
# Find and print:
# a & b

# %%
c=a&b
print(c)
# Out:
# 2

# %% [markdown]
# ### Q29. Bitwise OR |
# Find and print:
# a | b

# %%
c=a|b
print(c)
# Out:
# 14

# %% [markdown]
# ### Q30. Bitwise XOR ^
# Find and print:
# a ^ b

# %%
c=a^b
print(c)
# Out:
# 12

# %% [markdown]
# ### Q31. Bitwise NOT ~
# Create:
# a = 10
# Find and print:
# ~a

# %%
a=10
c=~a
print(c)
# Out:
# -11

# %% [markdown]
# ### Q32. Left Shift <<
# Create:
# a = 5
# Find and print:
# a << 2

# %%
a=5
c=a<<2
print(c)
# Out:
# 20

# %% [markdown]
# ### Q33. Right Shift >>
# Create:
# a = 20
# Find and print:
# a >> 2

# %%
a=20
c=a>>2
print(c)
# Out:
# 5

# %% [markdown]
# ### Q34. Bitwise operators together
# Create:
# a = 12
# b = 5
# Print the results of:
# 1. a & b
# 2. a | b
# 3. a ^ b
# 4. ~a
# 5. a << 1
# 6. a >> 1

# %%
a=12
b=5

# %%
print(a&b)
# Out:
# 4

# %%
print(a|b)
# Out:
# 13

# %%
print(a^b)
# Out:
# 9

# %%
print(~a)
# Out:
# -13

# %%
print(a<<1)
# Out:
# 24

# %%
print(a>>1)
# Out:
# 6

# %% [markdown]
# ### Part G – Membership Operators

# %% [markdown]
# ### Q35. in operator with a list
# Create:
# fruits = ["apple", "banana", "mango", "orange"]
# Check whether "mango" is present in the list using in.

# %%
fruits = ["apple", "banana", "mango", "orange"]
c="mango" in fruits
print(c)
# Out:
# True

# %% [markdown]
# ### Q36. not in operator with a list
# Using the same list, check whether "grapes" is not present using not in.

# %%
print("grapes" not in fruits)
# Out:
# True

# %% [markdown]
# ### Q37. Membership operator with a string
# Create:
# name = "Python Programming"
# Check:
# 1. Whether "Python" is present in the string.
# 2. Whether "Java" is not present in the string.

# %%
name = "Python Programming"

# %%
print("Python" in name)
print("Java" not in name)
# Out:
# True
# True

# %% [markdown]
# ### Part H – Identity Operators

# %% [markdown]
# ### Q38. Identity operator is
# Create:
# a = [1, 2, 3]
# b = a
# Check whether a and b refer to the same object using is.

# %%
a=[1, 2, 3]
b=a
c=b is a
print(c)
# Out:
# True

# %% [markdown]
# ### Q39. Identity operator is not
# Create:
# a = [1, 2, 3]
# b = [1, 2, 3]
# Check whether a and b are not the same object using is not.

# %%
a=[1, 2, 3]
b = [1, 2, 3]
c = a is not b
print(c)
# Out:
# True

# %% [markdown]
# ### Part I – Mixed Operator Questions
# Q40. Arithmetic + Comparison
# Given:
# a = 20
# b = 10

# %%
a=20
b=10

# %%
# a+b
c=a+b
print(c)
# Out:
# 30

# %%
# a-b
c=a-b
print(c)
# Out:
# 10

# %%
# a*b
c=a*b
print(c)
# Out:
# 200

# %%
# a/b
c=a/b
print(c)
# Out:
# 2.0

# %%
# a%b
c=a%b
print(c)
# Out:
# 0

# %%
# a//b
c=a//b
print(c)
# Out:
# 2

# %%
# a**b
c=a**b
print(c)
# Out:
# 10240000000000

# %%
# a>b
c=a>b
print(c)
# Out:
# True

# %%
# a==b
c=a==b
print(c)
# Out:
# False

# %% [markdown]
# ### Q41. Multiple operators
# Given:
# a = 15
# b = 4
# Calculate and print the results of all arithmetic operators:
# +, -, *, /, %, //, **.

# %%
a=15
b=4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %% [markdown]
# ### Q42. Student marks
# Create:
# maths = 80
# python = 90
# english = 75
#
# Calculate:
# 1. Total marks using +
# 2. Average marks using /
# 3. Check whether the total marks are greater than 200 using >
# 4. Check whether Python marks are equal to 90 using ==

# %%
maths = 80
python = 90
english = 75
total_marks = maths+python+english
print("Total marks: ", total_marks)

average = total_marks/3
print("Average: ",average)

print(total_marks>200)

print(python==90)
# Out:
# Total marks:  245
# Average:  81.66666666666667
# True
# True

# %% [markdown]
# ### Q43. Shopping calculation
# A student purchases:
# price = 250
# quantity = 4
# Calculate the total amount using *.
# Then check whether the total amount is greater than 500.

# %%
price = 250
quantity = 4
total_amount = price*quantity
print("Total amount: ", total_amount)
print(total_amount>500)
# Out:
# Total amount:  1000
# True

# %% [markdown]
# ### Q44. Groups of students
# There are 53 students and each group can contain 6 students.
# Write a program to calculate:
# 1. Number of complete groups using //
# 2. Number of students left using %

# %%
students = 53
total_group = 53//6
print("Total groups are: ", total_group)
# Out:
# Total groups are:  8

# %%
students_left = 53%6
print("Number of students left are: ",students_left)
# Out:
# Number of students left are:  5
